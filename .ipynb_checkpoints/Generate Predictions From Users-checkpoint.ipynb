# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd
import numpy as np
import joblib
import json
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
sheet_name = 'Movie_Preference_Information'
sheet_id = '1u85B-IL-btlQaqji6wXwgvbdZc_PZ9Y8EVCIRg-DMY0'

# %%
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

# %%
data = pd.read_csv(url)
data
# Out:
#             Timestamp                          What Genres do you enjoy?  \
# 0   3/6/2025 10:09:02  Action, Adventure, Animation, Comedy, Fantasy,...
# 1   3/6/2025 20:07:15                                  Action, Adventure
# 2   3/6/2025 20:26:51      Action, Adventure, Animation, Fantasy, Sci-Fi
# 3   3/6/2025 21:08:18                                  Biography, Comedy
# 4   3/7/2025 12:58:25  Action, Adventure, Comedy, Crime, Drama, Histo...
# 5   3/7/2025 12:59:23  Action, Adventure, Comedy, Crime, Drama, Famil...
# 6   3/7/2025 13:04:25  Animation, Comedy, Fantasy, Horror, Musical, R...
# 7   3/7/2025 13:08:43  Action, Adventure, Comedy, Fantasy, Horror, Mu...
# 8   3/7/2025 13:20:03  Action, Adventure, Biography, Comedy, Fantasy,...
# 9   3/7/2025 18:28:34         Action, Adventure, Comedy, Fantasy, Sci-Fi
# 10  3/7/2025 23:52:54                                     Action, Comedy
# 11  3/8/2025 11:06:42  Drama, Fantasy, History, Horror, Sci-Fi, Thriller
#
#    Do you prefer older classics or newer releases?  \
# 0                       Newer Releases (Post-2000)
# 1                       Newer Releases (Post-2000)
# 2                 All of the above - no preference
# 3                        Older Classics (Pre-1980)
# 4                       Newer Releases (Post-2000)
# 5                 All of the above - no preference
# 6                       Newer Releases (Post-2000)
# 7                 All of the above - no preference
# 8                 All of the above - no preference
# 9                           In Between (1980-2000)
# 10                      Newer Releases (Post-2000)
# 11                All of the above - no preference
#
#    Do you prefer shorter movies or longer epics?  \
# 0          Longer epics (~120 minutes or longer)
# 1          Shorter movies (~100 minutes or less)
# 2               All of the above - no preference
# 3          Longer epics (~120 minutes or longer)
# 4               All of the above - no preference
# 5               All of the above - no preference
# 6               All of the above - no preference
# 7          Shorter movies (~100 minutes or less)
# 8               All of the above - no preference
# 9          Shorter movies (~100 minutes or less)
# 10         Shorter movies (~100 minutes or less)
# 11         Shorter movies (~100 minutes or less)
#
#    Are there any actors or directors your particularly enjoy?   \
# 0                                                 NaN
# 1                                      Christian Bale
# 2                                                 Yes
# 3                                         Kirk Camron
# 4                                                 NaN
# 5           Kevin Costner, Mark Washburn, Chris Pratt
# 6                                                Nope
# 7                                       Keanu Reveess
# 8                                                  No
# 9                                                 NaN
# 10                                    Martin Scorsese
# 11                                   Yorgos Lanthimos
#
#    Do you prefer critically acclaimed movies or more popular, crowd-pleasing films?
# 0                    All of the above - no preference
# 1                       Popular, Crowd-Pleasing Films
# 2                    All of the above - no preference
# 3                       Popular, Crowd-Pleasing Films
# 4                       Popular, Crowd-Pleasing Films
# 5                    All of the above - no preference
# 6                       Popular, Crowd-Pleasing Films
# 7                    All of the above - no preference
# 8                    All of the above - no preference
# 9                       Popular, Crowd-Pleasing Films
# 10                   All of the above - no preference
# 11                        Critically Acclaimed Movies

# %%
scaler = joblib.load('scaler.pkl')
min_max_scaler = joblib.load('min_max_scaler.pkl')
director_encoder = joblib.load('director_encoder.pkl')
title_tokenizer = joblib.load('title_tokenizer.pkl')
with open('actor_to_index.json', 'r') as f:
    actor_to_index = json.load(f)
all_actors = np.load('all_actors.npy', allow_pickle=True).tolist()
with open('genre_columns.json', 'r') as f:
    genre_columns = json.load(f)

# %%
user_prefs_raw = {
    'Timestamp': '3/6/2025 20:07:15', # Example data based on your PDF [cite: 1]
    'Do you prefer older classics or newer releases?': 'Newer Releases (Post-2000)',
    'What Genres do you enjoy?': 'Action, Adventure',
    'Do you prefer shorter movies or longer epics?': 'Shorter movies (~100 minutes or less)',
    # Assuming the column header might be truncated or cleaned up
    'Are there any actors or directors your particularly enjoy?': 'Christian Bale',
    'Do you prefer critically acclaimed movies or more popular ones?': 'Popular, Crowd-Pleasing Films'
}

# %%
def process_preferences(raw_prefs, all_genre_columns):
    """Converts raw preference strings into a structured dictionary for filtering."""
    processed = {}

    # Process Genres
    raw_genres = raw_prefs.get('What Genres do you enjoy?', '').split(',')
    processed['genres'] = [g.strip() for g in raw_genres if g.strip()]
    # Create a multi-hot vector for potential model input (if model adapted)
    # genre_vector = [1 if col in processed['genres'] else 0 for col in all_genre_columns]


    # Process Era
    processed['era'] = raw_prefs.get('Do you prefer older classics or newer releases?', '')

    # Process Length
    processed['length'] = raw_prefs.get('Do you prefer shorter movies or longer epics?', '')

    # Process Actors/Directors (split if multiple, handle 'No', 'Yes', 'Nope' etc.)
    raw_actors_directors = raw_prefs.get('Are there any actors or directors your particularly enjoy?', '')
    if raw_actors_directors.lower().strip() not in ['no', 'yes', 'nope', '']:
         # Basic split, might need more robust parsing
        processed['actors_directors'] = [name.strip() for name in raw_actors_directors.split(',') if name.strip()]
    else:
        processed['actors_directors'] = []

    # Process Acclaim Preference
    processed['acclaim'] = raw_prefs.get('Do you prefer critically acclaimed movies or more popular ones?', '')

    return processed

# %%
processed_user_prefs = process_preferences(user_prefs_raw, genre_columns)

# %%
print(processed_user_prefs)
# Out:
# {'genres': ['Action', 'Adventure'], 'era': 'Newer Releases (Post-2000)', 'length': 'Shorter movies (~100 minutes or less)', 'actors_directors': ['Christian Bale'], 'acclaim': 'Popular, Crowd-Pleasing Films'}
